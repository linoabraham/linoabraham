# %% [markdown]
# <a href="https://colab.research.google.com/github/linoabraham/linoabraham/blob/main/TA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RESPUESTA GENIALY
# ALUMNO: Lino Abraham Quenta Leon
# CÓDIGO: U202022353
# PROFESOR: Cueva Chavez, Walter
# CARRERA: Ingeniería de Software
#
#
# link
# https://drive.google.com/drive/folders/1CDEjf3w0WrLunP-U0K3kqiDt5FTKK-Mk
#
#
#
# PREGUNTA 1. ¿CUÁLES SON LAS DIFERENCIAS ENTRE STRUCT Y CLASS? Las diferencias entre struct y class son:
# Struct.
# - Los miembros de una estructura (struct) son públicos por defecto. - Una estructura simplemente se siente como una pila abierta de bits con  muy poco en el camino de la encapsulación o la funcionalidad Class.
# - mientras que en una clase son privados.
# - Una clase se siente como un miembro vivo y responsable de la sociedad  con servicios inteligentes, una barrera encapsulación fuerte, y una interfaz  bien definida.
#
#
# PREGUNTA 2. ¿QUÉ SON LA HERENCIA TIPO PUBLICO Y PROTEGIDO? La herencia permite que los miembros de clase con este nivel de acceso  puedan ser heredados a clases derivadas.
# • Herencia pública: Se refiere a la herencia en la que todos los  miembros públicos y protegidos de la clase base conservan esos  mismos niveles de acceso respectivamente en las clases derivadas. class ClaseDerivada : public ClaseBase
# • Herencia protegida: Se refiere a la herencia en la que todos los  miembros públicos de la clase base adquieren el nivel de acceso  protegido en las clases derivadas, mientras que los miembros  protegidos conservan su nivel de acceso. Lo anterior indica que una  clase derivada puede luego heredar a otra clase los miembros  protegidos que heredó de su clase base.
#
# class ClaseDerivada: protected ClaseBase
#
#
# PREGUNTA 3. ¿PODEMOS UTILIZAR UNA FUNCIÓN SOBRESCRITA DE LA CLASE  BASE EN LA CLASE DERIVADA?
# Se pueden crear punteros que a objetos de la clase base abstracta que realmente  apunten a objetos de la clase derivada.
# Cuando se dan cuenta que diversos tipos tienen algo en común, por ejemplo, en el juego  del ajedrez peones, alfiles, rey, reina, caballos y torres, son piezas del juego. Creamos,  por tanto, una clase base y derivamos cada pieza individual a partir de dicha clase base.
#
#
#
# PREGUNTA 4 ¿CÓMO SE CREA UNA CLASE ABSTRACTA?
# son clases que no se pueden crear objetos, estas solo se forman con  funciones puras.
# EJEMPLO
#
# #pragma once
# #include<iostream>
# using namespace System::Drawing;
# class CEscenario
# {
# public:
# 	CEscenario();
# 	~CEscenario();
# 	void dibujar(Graphics^g,Bitmap^pared, Bitmap^ piso, Bitmap^ obstaculo);
# 	bool colision(Rectangle rec);
# private:
# 	int ancho, alto;
# 	int** mapa;
# };
#
#
#
#
#
# pregunta 5¿qué pasa si creo un objeto de una clase  abstracta, muestra un error o compila con éxito?
# Nose puede crear por que la clase es abstracta lo cual  manda error
#
#
#
#
# PREGUNTA 6 ¿POR QUÉ CREAMOS EL DESTRUCTOR Y QUÉ HAY  DENTRO DEL DESTRUCTOR?
# ¿Qué hace el destructor en C++?
# De ser así, la tarea del destructor será, básicamente, liberar la memoria  dinámica que ocupa el objeto que se va a destruir. Cuando una clase  hereda de otra, la clase derivada incorpora todos los miembros de la clase  base además de los suyos propios.
# la clase pero que va precedido del símbolo ~ (ASCII 126). El destructor es único  y no tiene argumentos: se puede definir dentro de la clase o fuera de la misma.  Si no se ha definido explícitamente un destructor dentro de la clase, C++  proporciona uno. Cuando una variable sale del ámbito en la que se ha declarado,  se libera la memoria que ocupa: un objeto llama para este propósito al  destructor.
#
#
# class Punto {
#  public:
#  //...
#  ~Punto() {cout << "objeto Punto destruido"; }
# };
#
#
#
# PREGUNTA 7 ¿CÓMO SE ASIGNA LA MEMORIA EN C++?
# Es el espacio en memoria que se asigna crea al declarar variables de cualquier tipo de dato  (primitivas [int, char...] o derivados [struct,matrices,punteros...]). La memoria que estas  variables ocupan no puede cambiarse durante la ejecución y tampoco puede ser liberada  manualmente.
# Para la reserva de memoria existen dos operadores, el primero es el  operador new que se utiliza para reservar posiciones individuales de memoria  del tamaño del tipo de dato que se va a alojar en esa posición. Mientras que el  operador new [] permite reservar al tiempo varias posiciones consecutivas de  memoria como en el caso de arreglos.
#
#
#
#
# PREGUNTA 8 ¿HA UTILIZADO LA SOBRECARGA DE OPERADORES EN SU  PROYECTO Y CÓMO?
# sí como: <,>, para llamar función de insertar objeto.
# Ejm.
# A*pA=new A; // ERROR! no puede crearse un objeto A
# // a continuacion ninguno de los sigientes objetos es A,
# //pero se consideran como apuntadores a este tipo de obejeto
# //para usar el polimorfismo.
# a* datos[]{new B(),new C(), new C(), new B()};
# for (int i=0; 1<4;1++)
#     datos[i]->print();
#     return 0;
#
#
#
# PREGUNTA 9 ¿DIFERENCIA ENTRE ENCAPSULAMIENTO Y  ABSTRACCIÓN?
# encapsulamiento: El encapsulamiento sucede cuando algo es envuelto en una  capa protectora.
# abstracción: La abstracción es la habilidad de ignorar los detalles de las partes  para enfocar la atención en un nivel más alto de un problema
#
#
#
# PREGUNTA 10 CUANDO LA MISMA FUNCIÓN EXISTE TANTO EN LA  CLASE BASE COMO EN LA CLASE DERIVADA, ¿QUÉ FUNCIÓN ES  EJECUTADA?
# La clase Object define una serie de funciones miembro que heredan todas las clases.
# Se declara una función como virtual dentro de la clase base precediendo su declaración con la  palabra clave virtual. Cuando una función virtual es redefinida por una clase derivada, la palabra  clave 'virtual' no necesita ser repetida (aunque no es un error hacerlo). Una clase que incluya  una función virtual es llamada una 'clase polimórfica'. Este término también aplica a una clase  que hereda una clase base conteniendo una función virtual.
#
#
#
#
#
# pregunta 11 ¿cómo podemos utilizar el constructor de la clase base  creando un objeto de la clase derivada?
# Se puede utilizar el constructor de la siguiente manera.
# Como vemos en el código, el constructor de la clase base inicializa los cuatro  miembros dato. Llamamos al constructor creando un objeto de la  clase Ventana
#
# Ventana ventana=new Ventana(0, 0, 20, 30);
#
# Desde el objeto ventana podemos llamar a las funciones miembro públicas
# ventana.mostrar();
# ventana.cambiarDimensiones(10, 10);
# ventana.mostrar();
#
#
#
#
# pregunta 12 ¿qué es la herencia y cómo lo utilizó en su proyecto?
# La herencia es una propiedad esencial de la Programación Orientada a Objetos que  consiste en la creación de nuevas clases a partir de otras ya existentes. Este término ha  sido prestado de la Biología donde afirmamos que un niño tiene la cara de su padre, que  ha heredado ciertas facetas físicas o del comportamiento de sus progenitores.
# La herencia es la característica fundamental que distingue un lenguaje orientado a objetos,  como el C++ o Java, de otro convencional como C, BASIC, etc.
#
# void CEscenario::dibujar(Graphics^ g, Bitmap^ pared, Bitmap^ piso, Bitmap^ obstaculo){
# 	for (int i = 0; i < alto; i++){
# 		for (int j = 0; j < ancho; j++){
# 			switch (mapa[i][j]) {
# 			case 0:g->DrawImage(piso,Rectangle(50*j,50*i,50,50),Rectangle(0,0, piso->Width, piso->Height),GraphicsUnit::Pixel);break;
# 			case 1:g->DrawImage(pared,Rectangle(50*j,50*i,50,50),Rectangle(0,0, pared->Width, pared->Height),GraphicsUnit::Pixel);break;
# 			case 2:g->DrawImage(obstaculo, Rectangle(50 * j, 50 * i, 50, 50), Rectangle(0, 0, obstaculo->Width, obstaculo->Height), GraphicsUnit::Pixel); break;
# 			}
# 		}
# 	}
#
#
#
#
#
# pregunta 13 ¿qué es namespace std?
# Un namespace, no es más que una forma de crear un bloque, y que todas las  funciones que estén dentro del mismo, estén asociadas a ese namespace (o  espacio de nombres), al cual se le asigna un nombre para identificarlo. En este  ejemplo, la función f está asociada al namespace hola
#
#
# namespace hola
# void f() { std::cout << “hola”;
# }
#
#
#
# pregunta 14 ¿por qué creamos una clase abstracta?
#
# La utilidad de un método abstracto es definir qué se debe hacer, pero no el cómo  se debe hacer. ... Al nosotros heredar de una clase abstracta es obligatorio  implementar todos sus métodos abstractos, es decir debemos definir  comportamiento, definir cómo se va a realizar la tarea.
#
# public abstract class Pieza
# {
#     public abstract decimal Area();
#     public abstract decimal Perimetro();
#     public bool EjemploMetodo()
#     {
#         return false;
#     }
#
#     public int ValorNatural = 1;
# }
#
#
#
# pregunta 15 ¿qué es la memoria tipo pila y cómo funciona?
# Una pila típica es un área de la memoria de los computadores con un origen fijo, un  espacio para almacenar datos y un puntero. Al principio, su número de elementos es  cero y la dirección del puntero coincide con la dirección de origen.
# Para el manejo de los datos se cuenta con dos operaciones básicas: apilar (push),  que coloca un objeto en la pila, y su operación inversa, retirar (o desapilar, pop), que  retira el último elemento apilado.
#
#
#
# pregunta 16 ¿cómo ha utilizado el polimorfismo en su trabajo final  de curso?
#
#
# polimorfismo (en POO) es la capacidad que tienen ciertos lenguajes para hacer  que, al enviar el mismo mensaje (o, en otras palabras, invocar al mismo método)  desde distintos objetos, cada uno de esos objetos pueda responder a ese mensaje  (o a esa invocación) de forma distinta.
#
# link de lo que utilize ya que es uba imagen
#
#
#
#
#
# pregunta 17 ¿qué es el retraso en la vinculación (late binding)?
# En C ++, el enlace tardío (también llamado "enlace dinámico") se refiere a lo que sucede  normalmente cuando la palabra clave se usa en la declaración de un método. A  virtual continuación, C ++ crea la denominada tabla virtual, que es una tabla de búsqueda para  dichas funciones que siempre se consultará cuando se las llame. Por lo general, el término  "vinculación tardía" se utiliza en favor de
#
#
# pregunta 18 ¿qué estructura de datos ha utilizado en su  trabajo final de curso?
# En el proyecto del anterior siclo he utilizado la estructura publica, como privada,  para el enemigo, aliado en mi dicho proyecto como el ejemplo que estoy  poniendo.
#
# class CEnemigo:public CFigura
# {
# public:
# CEnemigo(int ancho,int alto);
# ~CEnemigo();
# void movinvalido();
# private:
# };
#
#
#
# pregunta 19 ¿por qué cerrar el archivo? ¿es necesario cerrarlo o se  cerrará automáticamente al salir del programa?
# Al terminar de trabajar con un archivo, es recomendable cerrarlo, por diversos  motivos: en algunos sistemas los archivos sólo pueden ser abiertos de a un  programa por la vez; en otros, lo que se haya escrito no se guardará realmente  hasta no cerrar el archivo; o el límite de cantidad de archivos que puede manejar.
# Por lo dicho siempre es necesario cerrarlo.
#
#
#
#
# pregunta 20 ¿qué es object slicing?
# En la programación en C ++, la división de objetos se produce cuando un objeto de un  tipo de subclase se copia en un objeto de tipo superclase: la copia de superclase no  tendrá ninguna de las variables miembro definidas en la subclase. Estas variables, en  efecto, se han "cortado".
#
#
#
# PREGUNTA 21 ¿QUÉ OBJETOS STL HA UTILIZADO EN SU PROYECTO  FINAL Y POR QUÉ?
# en mi proyecto utilice sprites para realizar mi proyecto que sería un video juego,  como el escenario, aliados, enemigos, todo eso.
#
#
#
# pregunta 22 ¿por qué escribimos el constructor?
# Cuando se construye un objeto es necesario inicializar sus variables con valores coherentes, imaginemos un  objeto de la clase Persona cuyo atributo color de pelo al nacer sea verde, un estado incorrecto tras construir el  objeto persona. La solución en los lenguajes orientados a objetos es emplear los constructores. Un constructor  es un método perteneciente a la clase que posee unas características especiales:
# • Se llama igual que la clase.
# • No devuelve nada, ni siquiera void.
# • Pueden existir varios, pero siguiendo las reglas de la sobrecarga de funciones.
# • De entre los que existan, tan sólo uno se ejecutará al crear un objeto de la clase.
#
#
#
# PREGUNTA 23 ¿QUÉ PASARÍA SI NO ESCRIBIMOS EL CONSTRUCTOR?
# El nombre del constructor tiene que ser obligatoriamente el mismo que el de la  clase. De esta manera, puedes distinguir entre los diferentes constructores que  puedes tener en la clase con los otros métodos. Pues sino escribiéramos el  constructor no se pudiera distinguir bien los métodos de las clases
#
#
#
# PREGUNTA 24 ¿PUEDO SOBRECARGAR EL DESTRUCTOR?, ¿POR QUÉ?
# Una función destructora no puede especificar argumentos, no devuelve valor alguno,  ni puede ser sobrecargado (homonimia). Un destructor se invoca cuando deja de  existir el ámbito del respectivo objeto.
#
#
#
#
# PREGUNTA 25 ¿DIFERENCIA ENTRE TUPLA Y VECTOR?
# Un vector es una secuencia ordenada de elementos que permite duplicados. Un set  es una colección de elementos que no está ordenada y no permite duplicados.
# Un Tupla es una secuencia ordenada de elementos de una longitud determinada. La tupla es una colección heterogénea de objetos, que debe tratarse como una sola unidad:  por ejemplo, ("John", "Smith", 30) es una tupla (String, String, Integer)
#
#
#
# PREGUNTA 26 ¿CUÁL ES EL ORDEN DE LLAMADA A LOS CONSTRUCTORES  CUANDO SE CREA UN OBJETO DE UNA CLASE DERIVADA?
# Primero, se llama al constructor base, después los miembros de  la clase base se inicializan en el orden en que aparecen en la declaración  de clase y después se llama al constructor derivado
#
#
# PREGUNTA 27 ¿DIFERENCIA LA IMPLEMENTACION DE UNA RELACIÓN  COMPOSICIÓN Y AGREGACIÓN?
# La agregación es un tipo de asociación que indica que una clase es parte de otra  clase (composición débil). Los componentes pueden ser compartidos por varios  compuestos (de la misma asociación de agregación o de varias asociaciones  de agregación distintas).
#
#
# PREGUNTA 28 ¿CÓMO HACER EL MANEJO DE EXCEPCIONES EN C++? C ++ manejo de excepciones implica trespalabras clave: intentar, captura, tiro.
# 1. tiro: Cuando surgen problemas, el programa emitirá una excepción. ... 2. captura: en la que desea hacer frente al problema, una excepción es  atrapada por un manejador de excepciones
#
#
# PREGUNTA 29 ¿PUEDE EJEMPLIFICAR UNA RELACIÓN DE  DEPENDENCIA?
# La dependencia de clases es un concepto de la programación orientada a objetos  que nos indica la relación existente entre dos clases. Como su nombre indica nos  está diciendo que una clase depende de otra para realizar su funcionamiento.
# Ejemplo.
#
# PREGUNTA 30 ¿UNA CLASE PUEDE HEREDAR DE 2 CLASES BASE?
# hace referencia a la característica de los lenguajes de programación orientada a  objetos en la que una clase puede heredar comportamientos y características de  más de una superclase. Esto contrasta con la herencia simple, donde una clase solo  puede heredar de una superclase
# sí puede heredar 2 clases base, la que se define como múltiple.
#
#
# PREGUNTA 31 ¿PUEDE IDENTIFICAR UNA RELACIÓN DE  ASOCIACIÓN?
# Existen cuatro tipos de relaciones entre los elementos de un modelo UML:
# 1. Asociación.
# 2. Dependencia.
# 3. Generalización.
# 4. Realización.
# En las relaciones se habla de una clase destino y de una clase origen. La clase origen es desde  la que se realiza la acción de relacionar. Es decir, desde la que parte la flecha. La clase destino  es la que recibe la flecha. Las relaciones se pueden modificar con estereotipos o con  restricciones.
#
# GRACIAS

# %% [markdown]
# RESPUESTA GENIALY
# ALUMNO: Lino Abraham Quenta Leon
# CÓDIGO: U202022353
# PROFESOR: Cueva Chavez, Walter
# CARRERA: Ingeniería de Software
#
#
# link
# https://drive.google.com/drive/folders/1CDEjf3w0WrLunP-U0K3kqiDt5FTKK-Mk
#
#
#
# PREGUNTA 1. ¿CUÁLES SON LAS DIFERENCIAS ENTRE STRUCT Y CLASS? Las diferencias entre struct y class son:
# Struct.
# - Los miembros de una estructura (struct) son públicos por defecto. - Una estructura simplemente se siente como una pila abierta de bits con  muy poco en el camino de la encapsulación o la funcionalidad Class.
# - mientras que en una clase son privados.
# - Una clase se siente como un miembro vivo y responsable de la sociedad  con servicios inteligentes, una barrera encapsulación fuerte, y una interfaz  bien definida.
#
#
# PREGUNTA 2. ¿QUÉ SON LA HERENCIA TIPO PUBLICO Y PROTEGIDO? La herencia permite que los miembros de clase con este nivel de acceso  puedan ser heredados a clases derivadas.
# • Herencia pública: Se refiere a la herencia en la que todos los  miembros públicos y protegidos de la clase base conservan esos  mismos niveles de acceso respectivamente en las clases derivadas. class ClaseDerivada : public ClaseBase
# • Herencia protegida: Se refiere a la herencia en la que todos los  miembros públicos de la clase base adquieren el nivel de acceso  protegido en las clases derivadas, mientras que los miembros  protegidos conservan su nivel de acceso. Lo anterior indica que una  clase derivada puede luego heredar a otra clase los miembros  protegidos que heredó de su clase base.
#
# class ClaseDerivada: protected ClaseBase
#
#
# PREGUNTA 3. ¿PODEMOS UTILIZAR UNA FUNCIÓN SOBRESCRITA DE LA CLASE  BASE EN LA CLASE DERIVADA?
# Se pueden crear punteros que a objetos de la clase base abstracta que realmente  apunten a objetos de la clase derivada.
# Cuando se dan cuenta que diversos tipos tienen algo en común, por ejemplo, en el juego  del ajedrez peones, alfiles, rey, reina, caballos y torres, son piezas del juego. Creamos,  por tanto, una clase base y derivamos cada pieza individual a partir de dicha clase base.
#
#
#
# PREGUNTA 4 ¿CÓMO SE CREA UNA CLASE ABSTRACTA?
# son clases que no se pueden crear objetos, estas solo se forman con  funciones puras.
# EJEMPLO
#
# #pragma once
# #include<iostream>
# using namespace System::Drawing;
# class CEscenario
# {
# public:
# 	CEscenario();
# 	~CEscenario();
# 	void dibujar(Graphics^g,Bitmap^pared, Bitmap^ piso, Bitmap^ obstaculo);
# 	bool colision(Rectangle rec);
# private:
# 	int ancho, alto;
# 	int** mapa;
# };
#
#
#
#
#
# pregunta 5¿qué pasa si creo un objeto de una clase  abstracta, muestra un error o compila con éxito?
# Nose puede crear por que la clase es abstracta lo cual  manda error
#
#
#
#
# PREGUNTA 6 ¿POR QUÉ CREAMOS EL DESTRUCTOR Y QUÉ HAY  DENTRO DEL DESTRUCTOR?
# ¿Qué hace el destructor en C++?
# De ser así, la tarea del destructor será, básicamente, liberar la memoria  dinámica que ocupa el objeto que se va a destruir. Cuando una clase  hereda de otra, la clase derivada incorpora todos los miembros de la clase  base además de los suyos propios.
# la clase pero que va precedido del símbolo ~ (ASCII 126). El destructor es único  y no tiene argumentos: se puede definir dentro de la clase o fuera de la misma.  Si no se ha definido explícitamente un destructor dentro de la clase, C++  proporciona uno. Cuando una variable sale del ámbito en la que se ha declarado,  se libera la memoria que ocupa: un objeto llama para este propósito al  destructor.
#
#
# class Punto {
#  public:
#  //...
#  ~Punto() {cout << "objeto Punto destruido"; }
# };
#
#
#
# PREGUNTA 7 ¿CÓMO SE ASIGNA LA MEMORIA EN C++?
# Es el espacio en memoria que se asigna crea al declarar variables de cualquier tipo de dato  (primitivas [int, char...] o derivados [struct,matrices,punteros...]). La memoria que estas  variables ocupan no puede cambiarse durante la ejecución y tampoco puede ser liberada  manualmente.
# Para la reserva de memoria existen dos operadores, el primero es el  operador new que se utiliza para reservar posiciones individuales de memoria  del tamaño del tipo de dato que se va a alojar en esa posición. Mientras que el  operador new [] permite reservar al tiempo varias posiciones consecutivas de  memoria como en el caso de arreglos.
#
#
#
#
# PREGUNTA 8 ¿HA UTILIZADO LA SOBRECARGA DE OPERADORES EN SU  PROYECTO Y CÓMO?
# sí como: <,>, para llamar función de insertar objeto.
# Ejm.
# A*pA=new A; // ERROR! no puede crearse un objeto A
# // a continuacion ninguno de los sigientes objetos es A,
# //pero se consideran como apuntadores a este tipo de obejeto
# //para usar el polimorfismo.
# a* datos[]{new B(),new C(), new C(), new B()};
# for (int i=0; 1<4;1++)
#     datos[i]->print();
#     return 0;
#
#
#
# PREGUNTA 9 ¿DIFERENCIA ENTRE ENCAPSULAMIENTO Y  ABSTRACCIÓN?
# encapsulamiento: El encapsulamiento sucede cuando algo es envuelto en una  capa protectora.
# abstracción: La abstracción es la habilidad de ignorar los detalles de las partes  para enfocar la atención en un nivel más alto de un problema
#
#
#
# PREGUNTA 10 CUANDO LA MISMA FUNCIÓN EXISTE TANTO EN LA  CLASE BASE COMO EN LA CLASE DERIVADA, ¿QUÉ FUNCIÓN ES  EJECUTADA?
# La clase Object define una serie de funciones miembro que heredan todas las clases.
# Se declara una función como virtual dentro de la clase base precediendo su declaración con la  palabra clave virtual. Cuando una función virtual es redefinida por una clase derivada, la palabra  clave 'virtual' no necesita ser repetida (aunque no es un error hacerlo). Una clase que incluya  una función virtual es llamada una 'clase polimórfica'. Este término también aplica a una clase  que hereda una clase base conteniendo una función virtual.
#
#
#
#
#
# pregunta 11 ¿cómo podemos utilizar el constructor de la clase base  creando un objeto de la clase derivada?
# Se puede utilizar el constructor de la siguiente manera.
# Como vemos en el código, el constructor de la clase base inicializa los cuatro  miembros dato. Llamamos al constructor creando un objeto de la  clase Ventana
#
# Ventana ventana=new Ventana(0, 0, 20, 30);
#
# Desde el objeto ventana podemos llamar a las funciones miembro públicas
# ventana.mostrar();
# ventana.cambiarDimensiones(10, 10);
# ventana.mostrar();
#
#
#
#
# pregunta 12 ¿qué es la herencia y cómo lo utilizó en su proyecto?
# La herencia es una propiedad esencial de la Programación Orientada a Objetos que  consiste en la creación de nuevas clases a partir de otras ya existentes. Este término ha  sido prestado de la Biología donde afirmamos que un niño tiene la cara de su padre, que  ha heredado ciertas facetas físicas o del comportamiento de sus progenitores.
# La herencia es la característica fundamental que distingue un lenguaje orientado a objetos,  como el C++ o Java, de otro convencional como C, BASIC, etc.
#
# void CEscenario::dibujar(Graphics^ g, Bitmap^ pared, Bitmap^ piso, Bitmap^ obstaculo){
# 	for (int i = 0; i < alto; i++){
# 		for (int j = 0; j < ancho; j++){
# 			switch (mapa[i][j]) {
# 			case 0:g->DrawImage(piso,Rectangle(50*j,50*i,50,50),Rectangle(0,0, piso->Width, piso->Height),GraphicsUnit::Pixel);break;
# 			case 1:g->DrawImage(pared,Rectangle(50*j,50*i,50,50),Rectangle(0,0, pared->Width, pared->Height),GraphicsUnit::Pixel);break;
# 			case 2:g->DrawImage(obstaculo, Rectangle(50 * j, 50 * i, 50, 50), Rectangle(0, 0, obstaculo->Width, obstaculo->Height), GraphicsUnit::Pixel); break;
# 			}
# 		}
# 	}
#
#
#
#
#
# pregunta 13 ¿qué es namespace std?
# Un namespace, no es más que una forma de crear un bloque, y que todas las  funciones que estén dentro del mismo, estén asociadas a ese namespace (o  espacio de nombres), al cual se le asigna un nombre para identificarlo. En este  ejemplo, la función f está asociada al namespace hola
#
#
# namespace hola
# void f() { std::cout << “hola”;
# }
#
#
#
# pregunta 14 ¿por qué creamos una clase abstracta?
#
# La utilidad de un método abstracto es definir qué se debe hacer, pero no el cómo  se debe hacer. ... Al nosotros heredar de una clase abstracta es obligatorio  implementar todos sus métodos abstractos, es decir debemos definir  comportamiento, definir cómo se va a realizar la tarea.
#
# public abstract class Pieza
# {
#     public abstract decimal Area();
#     public abstract decimal Perimetro();
#     public bool EjemploMetodo()
#     {
#         return false;
#     }
#
#     public int ValorNatural = 1;
# }
#
#
#
# pregunta 15 ¿qué es la memoria tipo pila y cómo funciona?
# Una pila típica es un área de la memoria de los computadores con un origen fijo, un  espacio para almacenar datos y un puntero. Al principio, su número de elementos es  cero y la dirección del puntero coincide con la dirección de origen.
# Para el manejo de los datos se cuenta con dos operaciones básicas: apilar (push),  que coloca un objeto en la pila, y su operación inversa, retirar (o desapilar, pop), que  retira el último elemento apilado.
#
#
#
# pregunta 16 ¿cómo ha utilizado el polimorfismo en su trabajo final  de curso?
# polimorfismo (en POO) es la capacidad que tienen ciertos lenguajes para hacer  que, al enviar el mismo mensaje (o, en otras palabras, invocar al mismo método)  desde distintos objetos, cada uno de esos objetos pueda responder a ese mensaje  (o a esa invocación) de forma distinta.
#
# link de lo que utilize ya que es una imagen
#
#
#
#
# pregunta 17 ¿qué es el retraso en la vinculación (late binding)?
# En C ++, el enlace tardío (también llamado "enlace dinámico") se refiere a lo que sucede  normalmente cuando la palabra clave se usa en la declaración de un método. A  virtual continuación, C ++ crea la denominada tabla virtual, que es una tabla de búsqueda para  dichas funciones que siempre se consultará cuando se las llame. Por lo general, el término  "vinculación tardía" se utiliza en favor de
#
#
# pregunta 18 ¿qué estructura de datos ha utilizado en su  trabajo final de curso?
# En el proyecto del anterior siclo he utilizado la estructura publica, como privada,  para el enemigo, aliado en mi dicho proyecto como el ejemplo que estoy  poniendo.
#
# class CEnemigo:public CFigura
# {
# public:
# CEnemigo(int ancho,int alto);
# ~CEnemigo();
# void movinvalido();
# private:
# };
#
#
#
# pregunta 19 ¿por qué cerrar el archivo? ¿es necesario cerrarlo o se  cerrará automáticamente al salir del programa?
# Al terminar de trabajar con un archivo, es recomendable cerrarlo, por diversos  motivos: en algunos sistemas los archivos sólo pueden ser abiertos de a un  programa por la vez; en otros, lo que se haya escrito no se guardará realmente  hasta no cerrar el archivo; o el límite de cantidad de archivos que puede manejar.
# Por lo dicho siempre es necesario cerrarlo.
#
#
#
#
# pregunta 20 ¿qué es object slicing?
# En la programación en C ++, la división de objetos se produce cuando un objeto de un  tipo de subclase se copia en un objeto de tipo superclase: la copia de superclase no  tendrá ninguna de las variables miembro definidas en la subclase. Estas variables, en  efecto, se han "cortado".
#
#
#
# PREGUNTA 21 ¿QUÉ OBJETOS STL HA UTILIZADO EN SU PROYECTO  FINAL Y POR QUÉ?
# en mi proyecto utilice sprites para realizar mi proyecto que sería un video juego,  como el escenario, aliados, enemigos, todo eso.
#
# igual esta en el link los esprites
#
#
# pregunta 22 ¿por qué escribimos el constructor?
# Cuando se construye un objeto es necesario inicializar sus variables con valores coherentes, imaginemos un  objeto de la clase Persona cuyo atributo color de pelo al nacer sea verde, un estado incorrecto tras construir el  objeto persona. La solución en los lenguajes orientados a objetos es emplear los constructores. Un constructor  es un método perteneciente a la clase que posee unas características especiales:
# • Se llama igual que la clase.
# • No devuelve nada, ni siquiera void.
# • Pueden existir varios, pero siguiendo las reglas de la sobrecarga de funciones.
# • De entre los que existan, tan sólo uno se ejecutará al crear un objeto de la clase.
#
#
#
# PREGUNTA 23 ¿QUÉ PASARÍA SI NO ESCRIBIMOS EL CONSTRUCTOR?
# El nombre del constructor tiene que ser obligatoriamente el mismo que el de la  clase. De esta manera, puedes distinguir entre los diferentes constructores que  puedes tener en la clase con los otros métodos. Pues sino escribiéramos el  constructor no se pudiera distinguir bien los métodos de las clases
#
#
#
# PREGUNTA 24 ¿PUEDO SOBRECARGAR EL DESTRUCTOR?, ¿POR QUÉ?
# Una función destructora no puede especificar argumentos, no devuelve valor alguno,  ni puede ser sobrecargado (homonimia). Un destructor se invoca cuando deja de  existir el ámbito del respectivo objeto.
#
#
#
#
# PREGUNTA 25 ¿DIFERENCIA ENTRE TUPLA Y VECTOR?
# Un vector es una secuencia ordenada de elementos que permite duplicados. Un set  es una colección de elementos que no está ordenada y no permite duplicados.
# Un Tupla es una secuencia ordenada de elementos de una longitud determinada. La tupla es una colección heterogénea de objetos, que debe tratarse como una sola unidad:  por ejemplo, ("John", "Smith", 30) es una tupla (String, String, Integer)
#
#
#
# PREGUNTA 26 ¿CUÁL ES EL ORDEN DE LLAMADA A LOS CONSTRUCTORES  CUANDO SE CREA UN OBJETO DE UNA CLASE DERIVADA?
# Primero, se llama al constructor base, después los miembros de  la clase base se inicializan en el orden en que aparecen en la declaración  de clase y después se llama al constructor derivado
#
#
# PREGUNTA 27 ¿DIFERENCIA LA IMPLEMENTACION DE UNA RELACIÓN  COMPOSICIÓN Y AGREGACIÓN?
# La agregación es un tipo de asociación que indica que una clase es parte de otra  clase (composición débil). Los componentes pueden ser compartidos por varios  compuestos (de la misma asociación de agregación o de varias asociaciones  de agregación distintas).
#
#
# PREGUNTA 28 ¿CÓMO HACER EL MANEJO DE EXCEPCIONES EN C++? C ++ manejo de excepciones implica trespalabras clave: intentar, captura, tiro.
# 1. tiro: Cuando surgen problemas, el programa emitirá una excepción. ... 2. captura: en la que desea hacer frente al problema, una excepción es  atrapada por un manejador de excepciones
#
#
# PREGUNTA 29 ¿PUEDE EJEMPLIFICAR UNA RELACIÓN DE  DEPENDENCIA?
# La dependencia de clases es un concepto de la programación orientada a objetos  que nos indica la relación existente entre dos clases. Como su nombre indica nos  está diciendo que una clase depende de otra para realizar su funcionamiento.
# Ejemplo.
# en link esta el ejemplo
#
# PREGUNTA 30 ¿UNA CLASE PUEDE HEREDAR DE 2 CLASES BASE?
# hace referencia a la característica de los lenguajes de programación orientada a  objetos en la que una clase puede heredar comportamientos y características de  más de una superclase. Esto contrasta con la herencia simple, donde una clase solo  puede heredar de una superclase
# sí puede heredar 2 clases base, la que se define como múltiple.
# la clase multime : mas de una clase base.
#
# en el link la foto del flujo
#
# PREGUNTA 31 ¿PUEDE IDENTIFICAR UNA RELACIÓN DE  ASOCIACIÓN?
# Existen cuatro tipos de relaciones entre los elementos de un modelo UML:
# 1. Asociación.
# 2. Dependencia.
# 3. Generalización.
# 4. Realización.
# En las relaciones se habla de una clase destino y de una clase origen. La clase origen es desde  la que se realiza la acción de relacionar. Es decir, desde la que parte la flecha. La clase destino  es la que recibe la flecha. Las relaciones se pueden modificar con estereotipos o con  restricciones.
#
# GRACIAS
