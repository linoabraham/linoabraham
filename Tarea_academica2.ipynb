# %% [markdown]
# <a href="https://colab.research.google.com/github/linoabraham/linoabraham/blob/main/Tarea_academica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile micolbab1.cpp
#
#
# //ejercicio 1 calculo del tiempo.
#
# int s = 0;// ---> 1  tiempo
# double prom = 0;// -----2 tiempos
# for (int i = 0; i < n; i++) {//-----> 1 + n(1+3+3+2)
# s = s + A[i];//----> 3
# prom = s / (double) n;//----->2
# }
# printf("Suma:%d\nProm:%d", s, prom);//----------->2
# // tiempo detallado:_______
# //big o =0
#
#
#
# // ejercicio 2
#
# int s = 0; // ----> 1
# double prom = 0;//----->2
# for (int i = 0; i < n; i++) {//-----------> 1 +n(1+3+3+2)
# s = s + A[i];//---> 3
# }
# prom = s / (double)n;//----------->2
# printf("Suma:%d\nProm:%d", s, prom);---->2
#
# # big o =n
#
#
#
# //ejercicio 3
#
# for (int i = 0; i < n - 1; i++) {//------>1 de inicializacon+n(3)
# for (int k = i + 1; k < n; k++) {//------>n(1+1+k)
# if (vec[i] > vec[k]) {//------>3
# int aux = vec[i];//------>2
# vec[i] = vec[k];//------->3
# vec[k] = aux;//---->2
# }
# }
# }
# //big o=(n)
#
#
# //ejercicio 4
#
# int frec[101] = {0};//------>1+101+1
# for (int i = 0; i < n; i++) {//---->n(3___+n)
# frec[vec[i]]++;---------->2
# }
# int pos = 0;//-->1
# for (int i = 0; i < 101; i++) {//--->1+101(1_______n)
# for (int k = 0; k < frec[i]; k++) {//------->4
# vec[pos] = i;//----->2
# pos++;//---------->1
# }
# }
#
# //big o =(n)
#
#
#
# //ejercicio 5
#
#
# int i=0;//------>1
# int sum=0;//------------>1
# while (i < 100) {//--------->1+100
# if (i % 2 == 0) {//----------->2
# for (int k = 0; k < n; k++) {//---------->2K(1___n)
# sum += vec[i];//-------->3
# }
# }
# else {//--->1
# for (int k=0; k<i; k++) {//--------->1+1+1
# sum += vec[i];//------->3
# }
# }
# }
#
# //big o =(n)
#
#
#
# //ejercicio 6
#
# int fact = 1;//------------------>1
# for (int i = 2; i < n; i++) {//------------>N(3)
# fact *= i;//------------>2
# }
# printf("Factorial: %d", fact);//--------------->1
# //big o =(n)
#
# //ejercicio 7
#
# int pos = -1;//--------------1
# for (int i = 0; i < n; i++) {//------------>N(3)
# if (strcmp(vec[i], cadBuscar) == 0) {//-------->4
# pos = i;------------->//1
# break;------------>//1
# }
# }
# //big o =(N)
#
#
# //ejercicio 8
#
# int pos = 0;----------------->//1
# for (int i = 1; i < n; i++) {//-------------->//1+N(3)
# if (vec[i] > vec[pos])//--------------->//3
# pos = i;//----------------->1
# }
# printf("El mayor es: %d", vec[pos]);//----------->2
#
# //big o =(n)
#
#
# //ejercicio 9
#
#
# int max = 0;//--------------->1
# for (int m = 0; m < n; m++) {//------------>1 N(3+m)
# int cont = 0;//-------------->1
# int k = m + 1;//------------->2
# while (vec[m] <= vec[k]) {//-------------->4
# k = k + 1;//--------->2
# cont++;//------->1
# }
# if (cont > max)//--------------->1+1
# max = cont;//-------------------->1
# }
# printf("Maximo %d", max);//------------->1
#
# //big o=(n^2)
#
# //ejercicio 10
# int i=1;//--------------->1
# while (i < n)// --------------->2
# if (vec[i] % 2 == 0)//-------------->4
# i *= 3;//--------------->3
# else
# i *= 2;//-------------->3
# }
#
#
# //big o =long
#
# //ejercicio 11
#
# int i=1;//--------------->1
# while (i < n) {//--------------->2
# if (vec[i] % 2 == 0)//-------->3
# n = n / 3;//------------>3
# else
# n = n / 2;//-------------->3
# }
# //0(long)
#
# //12
# conio.h>
#
# using namespace std;
#
# main( ) {
#
# int m[5],r,i,pos;//1
# for (i = 0; i < 5; i++) {//3n
#
# cout<<"Ingresa elemeto : ";
#
# cin>>m[i]; //2
#
# }
#
# r = m[0];//2
# for (i = 0; i < 5; i++) {//3
#
# if (r < m[i])   {//2
#
#      r = m[i];//2
#    }
#
#   }
#
#
# cout<<"El valor maximo del arreglo es : "<<r<<endl;
#
# //13
#  for(int i=0;i<n;i++){//3
#   if(i==pos){//2
#    while(i<n-1){//2
#     vector[i]=vector[i+1];//3
#     i++;//1
#    }
#    break;
#   }
#  }
#  n=n-1;//2
#
#  //14
#  std::string no[] = {//3
#
# };
# std::string busqueda = "3";//1
# int indice = -1;//1
# for (int i = 0; i < sizeof(no) / sizeof(no[0]); i++) {//4
#   std::string nActual = nombres[i];//2
#   if (noActual == busqueda) {//2
#     indice = i;//1
#     break;
#   }
# }
